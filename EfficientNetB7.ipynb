# %%
from google.colab import drive
drive.mount('/content/drive', force_remount= True)
# Out:
# Mounted at /content/drive

# %%
from IPython.display import Image
Image('/content/drive/MyDrive/SkinCancerDataset/DermMel/DermMel/test/Melanoma/AUG_0_1001.jpeg')

# %%
from tensorflow.keras.layers import Dense, Lambda, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications import EfficientNetB7
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
from glob import glob
import cv2
import os

# %%
train=ImageDataGenerator(rescale=1/255)
test=ImageDataGenerator(rescale=1/255)

# %%
cv2.imread("/content/drive/MyDrive/SkinCancerDataset/DermMel/DermMel/test/Melanoma/AUG_0_1001.jpeg").shape
# Out:
# (224, 224, 3)

# %%
train_dataset=train.flow_from_directory("/content/drive/MyDrive/SkinCancerDataset/DermMel/DermMel/train_sep",
                                       target_size=(224,224),
                                       batch_size=20,
                                        class_mode='binary')
valid_dataset=train.flow_from_directory("/content/drive/MyDrive/SkinCancerDataset/DermMel/DermMel/valid",
                                       target_size=(224,224),
                                       batch_size=20,
                                        class_mode='binary')
test_dataset=train.flow_from_directory("/content/drive/MyDrive/SkinCancerDataset/DermMel/DermMel/test",
                                       target_size=(224,224),
                                       batch_size=20,
                                        class_mode='binary')
# Out:
# Found 10682 images belonging to 2 classes.
# Found 3562 images belonging to 2 classes.
# Found 3561 images belonging to 2 classes.

# %%
enb7= EfficientNetB7(include_top=False,
    weights="imagenet",
    input_shape=(224, 224, 3),
    pooling='max',
    )

for layer in enb7.layers:
  layer.trainable= False

model= Sequential()
model.add(enb7)
model.add(Flatten())
model.add(Dense(800, activation= 'relu'))
model.add(Dense(120, activation= 'relu'))
model.add(Dense(84, activation= 'relu'))
model.add(Dense(1, activation= 'sigmoid'))

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb7_notop.h5
# 258080768/258076736 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# efficientnetb7 (Functional)  (None, 2560)              64097687
# _________________________________________________________________
# flatten (Flatten)            (None, 2560)              0
# _________________________________________________________________
# dense (Dense)                (None, 800)               2048800
# _________________________________________________________________
# dense_1 (Dense)              (None, 120)               96120
# _________________________________________________________________
# dense_2 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 85
# =================================================================
# Total params: 66,252,856
# Trainable params: 2,155,169
# Non-trainable params: 64,097,687
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',
              optimizer= 'adam',
              metrics=['accuracy', 'mae', 'mape'])

# %%
checkpoint_path = "efficientnetb7/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath= checkpoint_path,
                                                 save_weights_only=False,
                                                 verbose=1)

# %%
model_fit = model.fit(train_dataset,
                    batch_size=32,
                    epochs=20,
                    verbose=1,  
                    validation_data=valid_dataset,
                    callbacks=[cp_callback])
# Out:
# Epoch 1/20
# 535/535 [==============================] - 4751s 9s/step - loss: 1.7519 - accuracy: 0.4934 - mae: 0.5039 - mape: 254557738.0299 - val_loss: 0.7174 - val_accuracy: 0.5000 - val_mae: 0.5000 - val_mape: 195546976.0000
#
# Epoch 00001: saving model to efficientnetb7/cp.ckpt
# INFO:tensorflow:Assets written to: efficientnetb7/cp.ckpt/assets
# Epoch 2/20
# 535/535 [==============================] - 170s 317ms/step - loss: 0.7448 - accuracy: 0.4932 - mae: 0.5001 - mape: 250265820.8657 - val_loss: 0.6939 - val_accuracy: 0.5000 - val_mae: 0.5000 - val_mape: 240351392.0000
#
# Epoch 00002: saving model to efficientnetb7/cp.ckpt
# INFO:tensorflow:Assets written to: efficientnetb7/cp.ckpt/assets
# Epoch 3/20
# 535/535 [==============================] - 170s 318ms/step - loss: 0.7009 - accuracy: 0.5149 - mae: 0.4992 - mape: 249589898.2388 - val_loss: 0.6932 - val_accuracy: 0.5000 - val_mae: 0.5000 - val_mape: 250630384.0000
#
# Epoch 00003: saving model to efficientnetb7/cp.ckpt
# INFO:tensorflow:Assets written to: efficientnetb7/cp.ckpt/assets
# Epoch 4/20
# 535/535 [==============================] - 170s 318ms/step - loss: 0.6950 - accuracy: 0.4896 - mae: 0.5001 - mape: 252131751.0448 - val_loss: 0.6932 - val_accuracy: 0.5000 - val_mae: 0.5000 - val_mape: 251091360.0000
#
# Epoch 00004: saving model to efficientnetb7/cp.ckpt
# INFO:tensorflow:Assets written to: efficientnetb7/cp.ckpt/assets
# Epoch 5/20
# 535/535 [==============================] - 171s 319ms/step - loss: 0.6938 - accuracy: 0.4998 - mae: 0.5000 - mape: 251436070.0896 - val_loss: 0.6931 - val_accuracy: 0.5000 - val_mae: 0.5000 - val_mape: 249732880.0000
#
# Epoch 00005: saving model to efficientnetb7/cp.ckpt
# INFO:tensorflow:Assets written to: efficientnetb7/cp.ckpt/assets
# Epoch 6/20
# 535/535 [==============================] - 170s 318ms/step - loss: 0.6954 - accuracy: 0.4966 - mae: 0.5001 - mape: 247580650.3582 - val_loss: 0.6932 - val_accuracy: 0.5000 - val_mae: 0.5000 - val_mape: 248748096.0000
#
# Epoch 00006: saving model to efficientnetb7/cp.ckpt
# INFO:tensorflow:Assets written to: efficientnetb7/cp.ckpt/assets
# Epoch 7/20
# 535/535 [==============================] - 171s 319ms/step - loss: 0.6932 - accuracy: 0.5001 - mae: 0.5000 - mape: 250105711.2537 - val_loss: 0.6932 - val_accuracy: 0.5000 - val_mae: 0.5000 - val_mape: 248392512.0000
#
# Epoch 00007: saving model to efficientnetb7/cp.ckpt
# INFO:tensorflow:Assets written to: efficientnetb7/cp.ckpt/assets
# Epoch 8/20
# 535/535 [==============================] - 171s 319ms/step - loss: 0.6933 - accuracy: 0.5041 - mae: 0.5000 - mape: 249869658.4179 - val_loss: 0.6931 - val_accuracy: 0.5000 - val_mae: 0.5000 - val_mape: 249580080.0000
#
# Epoch 00008: saving model to efficientnetb7/cp.ckpt
# INFO:tensorflow:Assets written to: efficientnetb7/cp.ckpt/assets
# Epoch 9/20
# 535/535 [==============================] - 171s 319ms/step - loss: 0.6932 - accuracy: 0.5085 - mae: 0.5000 - mape: 252746129.1045 - val_loss: 0.6932 - val_accuracy: 0.5000 - val_mae: 0.5000 - val_mape: 251304080.0000
#
# Epoch 00009: saving model to efficientnetb7/cp.ckpt
# INFO:tensorflow:Assets written to: efficientnetb7/cp.ckpt/assets
# Epoch 10/20
# 535/535 [==============================] - 171s 319ms/step - loss: 0.6933 - accuracy: 0.4909 - mae: 0.5001 - mape: 252861339.5821 - val_loss: 0.6931 - val_accuracy: 0.5000 - val_mae: 0.5000 - val_mape: 249589648.0000
#
# Epoch 00010: saving model to efficientnetb7/cp.ckpt
# INFO:tensorflow:Assets written to: efficientnetb7/cp.ckpt/assets
# Epoch 11/20
# 535/535 [==============================] - 171s 319ms/step - loss: 0.6932 - accuracy: 0.4984 - mae: 0.5000 - mape: 249468016.3582 - val_loss: 0.6931 - val_accuracy: 0.5000 - val_mae: 0.5000 - val_mape: 249879712.0000
#
# Epoch 00011: saving model to efficientnetb7/cp.ckpt
# INFO:tensorflow:Assets written to: efficientnetb7/cp.ckpt/assets
# Epoch 12/20
# 535/535 [==============================] - 171s 319ms/step - loss: 0.6932 - accuracy: 0.4882 - mae: 0.5000 - mape: 247964757.2537 - val_loss: 0.6932 - val_accuracy: 0.5000 - val_mae: 0.5000 - val_mape: 249070048.0000
#
# Epoch 00012: saving model to efficientnetb7/cp.ckpt
# INFO:tensorflow:Assets written to: efficientnetb7/cp.ckpt/assets
# Epoch 13/20
# 535/535 [==============================] - 171s 319ms/step - loss: 0.6932 - accuracy: 0.4955 - mae: 0.5000 - mape: 248465757.5224 - val_loss: 0.6931 - val_accuracy: 0.5000 - val_mae: 0.5000 - val_mape: 249490480.0000
#
# Epoch 00013: saving model to efficientnetb7/cp.ckpt
# INFO:tensorflow:Assets written to: efficientnetb7/cp.ckpt/assets
# Epoch 14/20
# 535/535 [==============================] - 173s 322ms/step - loss: 0.6932 - accuracy: 0.5026 - mae: 0.5000 - mape: 250439348.1493 - val_loss: 0.6932 - val_accuracy: 0.5000 - val_mae: 0.5000 - val_mape: 249317744.0000
#
# Epoch 00014: saving model to efficientnetb7/cp.ckpt
# INFO:tensorflow:Assets written to: efficientnetb7/cp.ckpt/assets
# Epoch 15/20
# 535/535 [==============================] - 173s 324ms/step - loss: 0.6932 - accuracy: 0.4983 - mae: 0.5000 - mape: 249354410.4478 - val_loss: 0.6931 - val_accuracy: 0.5000 - val_mae: 0.5000 - val_mape: 249897760.0000
#
# Epoch 00015: saving model to efficientnetb7/cp.ckpt
# INFO:tensorflow:Assets written to: efficientnetb7/cp.ckpt/assets
# Epoch 16/20
# 535/535 [==============================] - 173s 322ms/step - loss: 0.6932 - accuracy: 0.4895 - mae: 0.5000 - mape: 247296018.0597 - val_loss: 0.6931 - val_accuracy: 0.5000 - val_mae: 0.5000 - val_mape: 249522672.0000
#
# Epoch 00016: saving model to efficientnetb7/cp.ckpt
# INFO:tensorflow:Assets written to: efficientnetb7/cp.ckpt/assets
# Epoch 17/20
# 535/535 [==============================] - 173s 323ms/step - loss: 0.6932 - accuracy: 0.5007 - mae: 0.5000 - mape: 251484365.2537 - val_loss: 0.6931 - val_accuracy: 0.5000 - val_mae: 0.5000 - val_mape: 249948448.0000
#
# Epoch 00017: saving model to efficientnetb7/cp.ckpt
# INFO:tensorflow:Assets written to: efficientnetb7/cp.ckpt/assets
# Epoch 18/20
# 535/535 [==============================] - 173s 323ms/step - loss: 0.6932 - accuracy: 0.4922 - mae: 0.5000 - mape: 250170854.6269 - val_loss: 0.6931 - val_accuracy: 0.5000 - val_mae: 0.5000 - val_mape: 249811440.0000
#
# Epoch 00018: saving model to efficientnetb7/cp.ckpt
# INFO:tensorflow:Assets written to: efficientnetb7/cp.ckpt/assets
# Epoch 19/20
# 535/535 [==============================] - 173s 324ms/step - loss: 0.6932 - accuracy: 0.5089 - mae: 0.5000 - mape: 249095604.8358 - val_loss: 0.6931 - val_accuracy: 0.5000 - val_mae: 0.5000 - val_mape: 250409760.0000
#
# Epoch 00019: saving model to efficientnetb7/cp.ckpt
# INFO:tensorflow:Assets written to: efficientnetb7/cp.ckpt/assets
# Epoch 20/20
# 535/535 [==============================] - 173s 324ms/step - loss: 0.6932 - accuracy: 0.5026 - mae: 0.5000 - mape: 248911280.6269 - val_loss: 0.6931 - val_accuracy: 0.5000 - val_mae: 0.5000 - val_mape: 249968544.0000
#
# Epoch 00020: saving model to efficientnetb7/cp.ckpt
# INFO:tensorflow:Assets written to: efficientnetb7/cp.ckpt/assets

# %%
plt.plot(model_fit.history['loss'], label= 'train loss')
plt.plot(model_fit.history['val_loss'], label= 'val loss')
plt.legend
plt.show()
plt.savefig('lossVal_loss')

plt.plot(model_fit.history['accuracy'], label= 'train acc')
plt.plot(model_fit.history['val_accuracy'], label= 'val acc')
plt.legend
plt.show()
plt.savefig('AccVal_acc')
