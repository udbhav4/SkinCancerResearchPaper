# %%
from google.colab import drive
drive.mount('/content/drive', force_remount= True)
# Out:
# Mounted at /content/drive

# %%
from IPython.display import Image
Image('/content/drive/MyDrive/SkinCancerDataset/DermMel/DermMel/test/Melanoma/AUG_0_1001.jpeg')

# %%
from tensorflow.keras.layers import Dense, Lambda, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications import ResNet101V2
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
from glob import glob
import cv2
import os

# %%
train=ImageDataGenerator(rescale=1/255)
test=ImageDataGenerator(rescale=1/255)

# %%
cv2.imread("/content/drive/MyDrive/SkinCancerDataset/DermMel/DermMel/test/Melanoma/AUG_0_1001.jpeg").shape
# Out:
# (224, 224, 3)

# %%
train_dataset=train.flow_from_directory("/content/drive/MyDrive/SkinCancerDataset/DermMel/DermMel/train_sep",
                                       target_size=(224,224),
                                       batch_size=20,
                                        class_mode='binary')
valid_dataset=train.flow_from_directory("/content/drive/MyDrive/SkinCancerDataset/DermMel/DermMel/valid",
                                       target_size=(224,224),
                                       batch_size=20,
                                        class_mode='binary')
test_dataset=train.flow_from_directory("/content/drive/MyDrive/SkinCancerDataset/DermMel/DermMel/test",
                                       target_size=(224,224),
                                       batch_size=20,
                                        class_mode='binary')
# Out:
# Found 10682 images belonging to 2 classes.
# Found 3562 images belonging to 2 classes.
# Found 3561 images belonging to 2 classes.

# %%
rn101v2= ResNet101V2(include_top=False,
    weights="imagenet",
    input_shape=(224, 224, 3),
    pooling='max',
    )

for layer in rn101v2.layers:
  layer.trainable= False

model= Sequential()
model.add(rn101v2)
model.add(Flatten())
model.add(Dense(800, activation= 'relu'))
model.add(Dense(120, activation= 'relu'))
model.add(Dense(84, activation= 'relu'))
model.add(Dense(1, activation= 'sigmoid'))

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171319296/171317808 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet101v2 (Functional)     (None, 2048)              42626560
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 800)               1639200
# _________________________________________________________________
# dense_1 (Dense)              (None, 120)               96120
# _________________________________________________________________
# dense_2 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 85
# =================================================================
# Total params: 44,372,129
# Trainable params: 1,745,569
# Non-trainable params: 42,626,560
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',
              optimizer= 'adam',
              metrics=['accuracy', 'mae', 'mape'])

# %%
model_fit = model.fit(train_dataset,
                    batch_size=32,
                    epochs=60,
                    verbose=1,  
                    validation_data=valid_dataset)
# Out:
# Epoch 1/60
# 535/535 [==============================] - 4868s 9s/step - loss: 0.6816 - accuracy: 0.7830 - mae: 0.2691 - mape: 135559853.7892 - val_loss: 0.3541 - val_accuracy: 0.8495 - val_mae: 0.1812 - val_mape: 148295328.0000
# Epoch 2/60
# 535/535 [==============================] - 118s 221ms/step - loss: 0.2612 - accuracy: 0.8898 - mae: 0.1531 - mape: 76571987.7313 - val_loss: 0.2326 - val_accuracy: 0.9009 - val_mae: 0.1482 - val_mape: 68405928.0000
# Epoch 3/60
# 535/535 [==============================] - 117s 219ms/step - loss: 0.2314 - accuracy: 0.9021 - mae: 0.1397 - mape: 69983414.3060 - val_loss: 0.2404 - val_accuracy: 0.8998 - val_mae: 0.1296 - val_mape: 56981688.0000
# Epoch 4/60
# 535/535 [==============================] - 117s 218ms/step - loss: 0.2008 - accuracy: 0.9159 - mae: 0.1189 - mape: 58665793.3060 - val_loss: 0.2301 - val_accuracy: 0.9065 - val_mae: 0.1301 - val_mape: 52052576.0000
# Epoch 5/60
# 535/535 [==============================] - 117s 218ms/step - loss: 0.1764 - accuracy: 0.9237 - mae: 0.1084 - mape: 53697166.1269 - val_loss: 0.2738 - val_accuracy: 0.8984 - val_mae: 0.1236 - val_mape: 34720176.0000
# Epoch 6/60
# 535/535 [==============================] - 117s 219ms/step - loss: 0.1447 - accuracy: 0.9379 - mae: 0.0889 - mape: 43811131.5877 - val_loss: 0.2514 - val_accuracy: 0.9144 - val_mae: 0.1090 - val_mape: 49111904.0000
# Epoch 7/60
# 535/535 [==============================] - 117s 218ms/step - loss: 0.1427 - accuracy: 0.9380 - mae: 0.0860 - mape: 43115129.4347 - val_loss: 0.2494 - val_accuracy: 0.9127 - val_mae: 0.1087 - val_mape: 56583828.0000
# Epoch 8/60
# 535/535 [==============================] - 117s 218ms/step - loss: 0
# Epoch 51/60
# 535/535 [==============================] - 117s 219ms/step - loss: 1.4596e-06 - accuracy: 1.0000 - mae: 1.4586e-06 - mape: 593.5311 - val_loss: 0.8774 - val_accuracy: 0.9242 - val_mae: 0.0763 - val_mape: 43129644.0000
# Epoch 52/60
# 535/535 [==============================] - 117s 219ms/step - loss: 1.1909e-06 - accuracy: 1.0000 - mae: 1.1898e-06 - mape: 511.1561 - val_loss: 0.9020 - val_accuracy: 0.9239 - val_mae: 0.0765 - val_mape: 43939368.0000
# Epoch 53/60
# 535/535 [==============================] - 118s 220ms/step - loss: 8.8379e-07 - accuracy: 1.0000 - mae: 8.8292e-07 - mape: 429.2825 - val_loss: 0.9261 - val_accuracy: 0.9236 - val_mae: 0.0764 - val_mape: 43666732.0000
# Epoch 54/60
# 535/535 [==============================] - 117s 219ms/step - loss: 6.1499e-07 - accuracy: 1.0000 - mae: 6.1433e-07 - mape: 249.1867 - val_loss: 0.9503 - val_accuracy: 0.9236 - val_mae: 0.0764 - val_mape: 43541092.0000
# Epoch 55/60
# 535/535 [==============================] - 117s 219ms/step - loss: 4.9787e-07 - accuracy: 1.0000 - mae: 4.9694e-07 - mape: 212.8327 - val_loss: 0.9744 - val_accuracy: 0.9239 - val_mae: 0.0764 - val_mape: 43918868.0000
# Epoch 56/60
# 535/535 [==============================] - 117s 219ms/step - loss: 3.1274e-07 - accuracy: 1.0000 - mae: 3.1212e-07 - mape: 128.6402 - val_loss: 0.9982 - val_accuracy: 0.9236 - val_mae: 0.0764 - val_mape: 43814816.0000
# Epoch 57/60
# 535/535 [==============================] - 117s 218ms/step - loss: 1.9993e-07 - accuracy: 1.0000 - mae: 1.9925e-07 - mape: 92.0229 - val_loss: 1.0229 - val_accuracy: 0.9236 - val_mae: 0.0764 - val_mape: 44186612.0000
# Epoch 58/60
# 535/535 [==============================] - 117s 218ms/step - loss: 1.7469e-07 - accuracy: 1.0000 - mae: 1.7410e-07 - mape: 68.1071 - val_loss: 1.0457 - val_accuracy: 0.9236 - val_mae: 0.0764 - val_mape: 44044176.0000
# Epoch 59/60
# 535/535 [==============================] - 117s 219ms/step - loss: 1.1271e-07 - accuracy: 1.0000 - mae: 1.1202e-07 - mape: 39.7490 - val_loss: 1.0696 - val_accuracy: 0.9234 - val_mae: 0.0764 - val_mape: 43882796.0000
# Epoch 60/60
# 535/535 [==============================] - 117s 218ms/step - loss: 6.2428e-08 - accuracy: 1.0000 - mae: 6.1938e-08 - mape: 26.1486 - val_loss: 1.0939 - val_accuracy: 0.9236 - val_mae: 0.0764 - val_mape: 44032488.0000

# %%
model.save('RN101V2.h5')

# %%
plt.plot(model_fit.history['loss'], label= 'train loss')
plt.plot(model_fit.history['val_loss'], label= 'val loss')
plt.legend
plt.show()
plt.savefig('lossVal_loss')

plt.plot(model_fit.history['accuracy'], label= 'train acc')
plt.plot(model_fit.history['val_accuracy'], label= 'val acc')
plt.legend
plt.show()
plt.savefig('AccVal_acc')
